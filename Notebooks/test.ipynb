# %%
import pandas as pd
import joblib

# %%
test_data = pd.read_csv('enter the path where test data file is stored')

# %%
model = joblib.load('enter the path path where you have stored your pkl file')  # Update this path

# %%
test_predictions = model.predict(test_data)

# %%
test_data['price'] = test_predictions

# %%
test_data
# Out:
#           id          brand  \
# 0      54273  Mercedes-Benz
# 1      54274          Lexus
# 2      54275  Mercedes-Benz
# 3      54276           Land
# 4      54277            BMW
# ...      ...            ...
# 36178  90451            GMC
# 36179  90452      Chevrolet
# 36180  90453         Toyota
# 36181  90454        Lincoln
# 36182  90455      Chevrolet
#
#                                                    model  model_year  milage  \
# 0                                          E-Class E 350        2014   73000
# 1                                            RX 350 Base        2015  128032
# 2                                          C-Class C 300        2015   51983
# 3      Rover Range Rover 5.0L Supercharged Autobiogra...        2018   29500
# 4                                           X6 xDrive40i        2020   90000
# ...                                                  ...         ...     ...
# 36178                                       Yukon Denali        2019    4500
# ...

# %%
submission=test_data[['id','price']]

# %%
submission.to_csv('submission.csv', index=False)
